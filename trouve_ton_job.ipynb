# %%
import pandas as pd
import numpy as np
import re 
import json
import datetime as dt

# %%
data = pd.read_json('data.json')
df = data.copy()
df.dtypes
# Out:
# Intitulé du poste      object
# Date de publication    object
# lieu                   object
# competences            object
# Type de poste          object
# dtype: object

# %%
df.shape
# Out:
# (230, 5)

# %%
df = df.replace('\n','', regex=True)
df['Intitulé du poste'] = [' '.join(item).replace('\n', '').lower() for item in df['Intitulé du poste']]
df['lieu'] = [', '.join(item).replace('\n', '').lower() for item in df['lieu']]
df['competences'] = [' '.join(item).replace('\n', '').replace(' ', ', ').lower() for item in df['competences']]
df['Type de poste'] = [''.join(item).replace('\n', ', ').replace(', , ', '').lower().strip() for item in df['Type de poste']]
# df[['lieu', 'salary']] = df["lieu"].str.split(",", expand = True, n=1)
df
# Out:
#                                      Intitulé du poste  \
# 0                             data analyst - publicité
# 1                                   data analyst - h/f
# 2                          customer data analyst (h/f)
# 3                              master data analyst h/f
# 4                           portfolio data analyst h/f
# ..                                                 ...
# 225                          sap fiori developer (h/f)
# 226           engie digital - architecte données (h/f)
# 227  quality assurance - lead qa - lead acceptance h/f
# 228                                     data scientist
# 229                                datascientist (h/f)
#
#         Date de publication  \
# 0    postée il y a 21 jours
# 1      postée il y a 1 mois
# 2    postée il y a 27 jours
# 3    postée il y a 21 jours
# 4     postée il y a 3 jours
# ..                      ...
# 225  postée il y a 27 jours
# 226   postée il y a 3 jours
# 227  postée il y a 2 heures
# 228  postée il y a 16 jours
# 229   postée il y a 3 jours
#
#                                                   lieu  \
# 0                                                paris
# 1                                    paris, la défense
# 2                                                paris
# 3                                      moussy-le-vieux
# 4                                               france
# ..                                                 ...
# 225                                         saint-ouen
# 226                                              paris
# 227                               boulogne-billancourt
# 228  neuilly sur seine, 38.000,00 € - 50.000,00 € / an
# 229                                         saint-ouen
#
#                                        competences  \
# 0                               sql, t-sql, outils
# 1        support, outils, agile, design, big, data
# 2             crm, data, quality, sql, sas, python
# 3                                 si, support, sap
# 4          outils, support, decisionnel, sql, test
# ..                                             ...
# 225         sap, abap, progiciel, système, support
# 226     digital, outils, securité, sécurité, t-sql
# 227             test, serveur, jquery, mobile, tdd
# 228    nosql, unix, java, machine, learning, linux
# 229  big, data, support, python, réseaux, securité
#
#                                          Type de poste
# 0    sept lieues sas, cabinet de recrutement, cdi -...
# 1         edf france, client final, cdi - temps plein,
# 2             hermès, client final, cdi - temps plein,
# 3             tereos, client final, cdi - temps plein,
# 4       safran-group, client final, cdi - temps plein,
# ..                                                 ...
# 225     groupe engie, client final, cdi - temps plein,
# 226     groupe engie, client final, cdi - temps plein,
# 227  francaise des jeux, client final, cdi - temps ...
# 228                    beezen, esn, cdi - temps plein,
# 229     groupe engie, client final, cdi - temps plein,
#
# [230 rows x 5 columns]

# %%
y = [' '.join(element.split()) for element in df['Date de publication']]

# %%
date0 = dt.date(2023, 1, 15)
dates = []
for item in y:
    delai = item.split()
    if delai[-1] == "jours":
        delta = dt.timedelta(days=int(delai[-2]))
        date = date0 - delta
        dates.append(date)
    elif delai[-1] == 'mois':
        delta = dt.timedelta(weeks=4*int(delai[-2]))
        date = date0 - delta
        dates.append(date)
    elif delai[-1] == 'heures':
        delta = dt.timedelta(hours=int(delai[-2]))
        date = date0 - delta
        dates.append(date)
    elif delai[-1] == 'hier':
        date = dt.date(2013, 1, 14)
        dates.append(date)
df['Date de publication'] = dates
df
# Out:
#                                      Intitulé du poste Date de publication  \
# 0                             data analyst - publicité          2022-12-25
# 1                                   data analyst - h/f          2022-12-18
# 2                          customer data analyst (h/f)          2022-12-19
# 3                              master data analyst h/f          2022-12-25
# 4                           portfolio data analyst h/f          2023-01-12
# ..                                                 ...                 ...
# 225                          sap fiori developer (h/f)          2022-12-19
# 226           engie digital - architecte données (h/f)          2023-01-12
# 227  quality assurance - lead qa - lead acceptance h/f          2023-01-15
# 228                                     data scientist          2022-12-30
# 229                                datascientist (h/f)          2023-01-12
#
#                                                   lieu  \
# 0                                                paris
# 1                                    paris, la défense
# 2                                                paris
# 3                                      moussy-le-vieux
# 4                                               france
# ..                                                 ...
# 225                                         saint-ouen
# 226                                              paris
# 227                               boulogne-billancourt
# 228  neuilly sur seine, 38.000,00 € - 50.000,00 € / an
# 229                                         saint-ouen
#
#                                        competences  \
# 0                               sql, t-sql, outils
# 1        support, outils, agile, design, big, data
# 2             crm, data, quality, sql, sas, python
# 3                                 si, support, sap
# 4          outils, support, decisionnel, sql, test
# ..                                             ...
# 225         sap, abap, progiciel, système, support
# 226     digital, outils, securité, sécurité, t-sql
# 227             test, serveur, jquery, mobile, tdd
# 228    nosql, unix, java, machine, learning, linux
# 229  big, data, support, python, réseaux, securité
#
#                                          Type de poste
# 0    sept lieues sas, cabinet de recrutement, cdi -...
# 1         edf france, client final, cdi - temps plein,
# 2             hermès, client final, cdi - temps plein,
# 3             tereos, client final, cdi - temps plein,
# 4       safran-group, client final, cdi - temps plein,
# ..                                                 ...
# 225     groupe engie, client final, cdi - temps plein,
# 226     groupe engie, client final, cdi - temps plein,
# 227  francaise des jeux, client final, cdi - temps ...
# 228                    beezen, esn, cdi - temps plein,
# 229     groupe engie, client final, cdi - temps plein,
#
# [230 rows x 5 columns]

# %%
# format des colonnes salaires
s = [item for item in df['lieu']]
pat = re.compile(r'^((\d)[0-9]*)[0-9]\.(\d){2}$')
salaires = []
for item in s:
    test = bool(re.search(r'\d', item))
    if test == True:
        salaires.append(item)
    else:
        salaires.append(np.nan)

salaries = []
for item in salaires:
    if type(item) is float:
        salaries.append(item)
    elif type(item) is str:
        element = item.split(',')[1:]
        if len(element) >= 2:
            salaries.append(' '.join(element))
        else:
            salaries.append(np.nan)
df['salaires'] = salaries
df
# Out:
#                                      Intitulé du poste Date de publication  \
# 0                             data analyst - publicité          2022-12-25
# 1                                   data analyst - h/f          2022-12-18
# 2                          customer data analyst (h/f)          2022-12-19
# 3                              master data analyst h/f          2022-12-25
# 4                           portfolio data analyst h/f          2023-01-12
# ..                                                 ...                 ...
# 225                          sap fiori developer (h/f)          2022-12-19
# 226           engie digital - architecte données (h/f)          2023-01-12
# 227  quality assurance - lead qa - lead acceptance h/f          2023-01-15
# 228                                     data scientist          2022-12-30
# 229                                datascientist (h/f)          2023-01-12
#
#                                                   lieu  \
# 0                                                paris
# 1                                    paris, la défense
# 2                                                paris
# 3                                      moussy-le-vieux
# 4                                               france
# ..                                                 ...
# 225                                         saint-ouen
# 226                                              paris
# 227                               boulogne-billancourt
# 228  neuilly sur seine, 38.000,00 € - 50.000,00 € / an
# 229                                         saint-ouen
#
#                                        competences  \
# 0                               sql, t-sql, outils
# 1        support, outils, agile, design, big, data
# 2             crm, data, quality, sql, sas, python
# 3                                 si, support, sap
# 4          outils, support, decisionnel, sql, test
# ..                                             ...
# 225         sap, abap, progiciel, système, support
# 226     digital, outils, securité, sécurité, t-sql
# 227             test, serveur, jquery, mobile, tdd
# 228    nosql, unix, java, machine, learning, linux
# 229  big, data, support, python, réseaux, securité
#
#                                          Type de poste  \
# 0    sept lieues sas, cabinet de recrutement, cdi -...
# 1         edf france, client final, cdi - temps plein,
# 2             hermès, client final, cdi - temps plein,
# 3             tereos, client final, cdi - temps plein,
# 4       safran-group, client final, cdi - temps plein,
# ..                                                 ...
# 225     groupe engie, client final, cdi - temps plein,
# 226     groupe engie, client final, cdi - temps plein,
# 227  francaise des jeux, client final, cdi - temps ...
# 228                    beezen, esn, cdi - temps plein,
# 229     groupe engie, client final, cdi - temps plein,
#
#                             salaires
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ..                               ...
# 225                              NaN
# 226                              NaN
# 227                              NaN
# 228   38.000 00 € - 50.000 00 € / an
# 229                              NaN
#
# [230 rows x 6 columns]

# %%
# For the column of 'Type de contra' et 'Nom de la société' from original coulmn 'Type de poste'
df[['Nom de la société','Type de la société', 'Type de contrat']] = df["Type de poste"].str.split(",", expand = True, n=2)

df[['Type de contrat', 'temps travail_1']] = df["Type de contrat"].str.split("-", expand = True, n=2)
df[['Type de contrat', 'temps travail_2']] = df["Type de contrat"].str.split("/", expand = True, n=1)

df["Type de contrat"] = [''.join(item).replace(',', '').replace(' ', '') for item in df['Type de contrat']]

#Remove the 3 columns: 'temps travail_1' and 'temps travail_2','Type de la société'
df = df.drop(columns=['temps travail_1', 'temps travail_2', 'Type de la société'])
df
# Out:
#                                      Intitulé du poste Date de publication  \
# 0                             data analyst - publicité          2022-12-25
# 1                                   data analyst - h/f          2022-12-18
# 2                          customer data analyst (h/f)          2022-12-19
# 3                              master data analyst h/f          2022-12-25
# 4                           portfolio data analyst h/f          2023-01-12
# ..                                                 ...                 ...
# 225                          sap fiori developer (h/f)          2022-12-19
# 226           engie digital - architecte données (h/f)          2023-01-12
# 227  quality assurance - lead qa - lead acceptance h/f          2023-01-15
# 228                                     data scientist          2022-12-30
# 229                                datascientist (h/f)          2023-01-12
#
#                                                   lieu  \
# 0                                                paris
# 1                                    paris, la défense
# 2                                                paris
# 3                                      moussy-le-vieux
# 4                                               france
# ..                                                 ...
# 225                                         saint-ouen
# 226                                              paris
# 227                               boulogne-billancourt
# 228  neuilly sur seine, 38.000,00 € - 50.000,00 € / an
# 229                                         saint-ouen
#
#                                        competences  \
# 0                               sql, t-sql, outils
# 1        support, outils, agile, design, big, data
# 2             crm, data, quality, sql, sas, python
# 3                                 si, support, sap
# 4          outils, support, decisionnel, sql, test
# ..                                             ...
# 225         sap, abap, progiciel, système, support
# 226     digital, outils, securité, sécurité, t-sql
# 227             test, serveur, jquery, mobile, tdd
# 228    nosql, unix, java, machine, learning, linux
# 229  big, data, support, python, réseaux, securité
#
#                                          Type de poste  \
# 0    sept lieues sas, cabinet de recrutement, cdi -...
# 1         edf france, client final, cdi - temps plein,
# 2             hermès, client final, cdi - temps plein,
# 3             tereos, client final, cdi - temps plein,
# 4       safran-group, client final, cdi - temps plein,
# ..                                                 ...
# 225     groupe engie, client final, cdi - temps plein,
# 226     groupe engie, client final, cdi - temps plein,
# 227  francaise des jeux, client final, cdi - temps ...
# 228                    beezen, esn, cdi - temps plein,
# 229     groupe engie, client final, cdi - temps plein,
#
#                             salaires   Nom de la société Type de contrat
# 0                                NaN     sept lieues sas             cdi
# 1                                NaN          edf france             cdi
# 2                                NaN              hermès             cdi
# 3                                NaN              tereos             cdi
# 4                                NaN        safran-group             cdi
# ..                               ...                 ...             ...
# 225                              NaN        groupe engie             cdi
# 226                              NaN        groupe engie             cdi
# 227                              NaN  francaise des jeux             cdi
# 228   38.000 00 € - 50.000 00 € / an              beezen             cdi
# 229                              NaN        groupe engie             cdi
#
# [230 rows x 8 columns]

# %%
df[['salaire_minimum', 'salaire_maximum']] = df["salaires"].str.split("-", expand = True, n=1)
df
# Out:
#                                      Intitulé du poste Date de publication  \
# 0                             data analyst - publicité          2022-12-25
# 1                                   data analyst - h/f          2022-12-18
# 2                          customer data analyst (h/f)          2022-12-19
# 3                              master data analyst h/f          2022-12-25
# 4                           portfolio data analyst h/f          2023-01-12
# ..                                                 ...                 ...
# 225                          sap fiori developer (h/f)          2022-12-19
# 226           engie digital - architecte données (h/f)          2023-01-12
# 227  quality assurance - lead qa - lead acceptance h/f          2023-01-15
# 228                                     data scientist          2022-12-30
# 229                                datascientist (h/f)          2023-01-12
#
#                                                   lieu  \
# 0                                                paris
# 1                                    paris, la défense
# 2                                                paris
# 3                                      moussy-le-vieux
# 4                                               france
# ..                                                 ...
# 225                                         saint-ouen
# 226                                              paris
# 227                               boulogne-billancourt
# 228  neuilly sur seine, 38.000,00 € - 50.000,00 € / an
# 229                                         saint-ouen
#
#                                        competences  \
# 0                               sql, t-sql, outils
# 1        support, outils, agile, design, big, data
# 2             crm, data, quality, sql, sas, python
# 3                                 si, support, sap
# 4          outils, support, decisionnel, sql, test
# ..                                             ...
# 225         sap, abap, progiciel, système, support
# 226     digital, outils, securité, sécurité, t-sql
# 227             test, serveur, jquery, mobile, tdd
# 228    nosql, unix, java, machine, learning, linux
# 229  big, data, support, python, réseaux, securité
#
#                                          Type de poste  \
# 0    sept lieues sas, cabinet de recrutement, cdi -...
# 1         edf france, client final, cdi - temps plein,
# 2             hermès, client final, cdi - temps plein,
# 3             tereos, client final, cdi - temps plein,
# 4       safran-group, client final, cdi - temps plein,
# ..                                                 ...
# 225     groupe engie, client final, cdi - temps plein,
# 226     groupe engie, client final, cdi - temps plein,
# 227  francaise des jeux, client final, cdi - temps ...
# 228                    beezen, esn, cdi - temps plein,
# 229     groupe engie, client final, cdi - temps plein,
#
#                             salaires   Nom de la société Type de contrat  \
# 0                                NaN     sept lieues sas             cdi
# 1                                NaN          edf france             cdi
# 2                                NaN              hermès             cdi
# 3                                NaN              tereos             cdi
# 4                                NaN        safran-group             cdi
# ..                               ...                 ...             ...
# 225                              NaN        groupe engie             cdi
# 226                              NaN        groupe engie             cdi
# 227                              NaN  francaise des jeux             cdi
# 228   38.000 00 € - 50.000 00 € / an              beezen             cdi
# 229                              NaN        groupe engie             cdi
#
#     salaire_minimum    salaire_maximum
# 0               NaN                NaN
# 1               NaN                NaN
# 2               NaN                NaN
# 3               NaN                NaN
# 4               NaN                NaN
# ..              ...                ...
# 225             NaN                NaN
# 226             NaN                NaN
# 227             NaN                NaN
# 228    38.000 00 €    50.000 00 € / an
# 229             NaN                NaN
#
# [230 rows x 10 columns]

# %%
# Formatage du des colonnes salaires et conversion des valeurs string en float
df['salaire_minimum'] = df['salaire_minimum'].replace(to_replace='00 €', value='', regex=True)
df['salaire_maximum'] = df['salaire_maximum'].replace(to_replace='00 € / an', value='', regex=True)
df['salaire_minimum'] = df['salaire_minimum'].astype(float) * 1000
df['salaire_maximum'] = df['salaire_maximum'].astype(float) * 1000
df = df.drop('salaires', axis=1)
df
# Out:
#                                      Intitulé du poste Date de publication  \
# 0                             data analyst - publicité          2022-12-25
# 1                                   data analyst - h/f          2022-12-18
# 2                          customer data analyst (h/f)          2022-12-19
# 3                              master data analyst h/f          2022-12-25
# 4                           portfolio data analyst h/f          2023-01-12
# ..                                                 ...                 ...
# 225                          sap fiori developer (h/f)          2022-12-19
# 226           engie digital - architecte données (h/f)          2023-01-12
# 227  quality assurance - lead qa - lead acceptance h/f          2023-01-15
# 228                                     data scientist          2022-12-30
# 229                                datascientist (h/f)          2023-01-12
#
#                                                   lieu  \
# 0                                                paris
# 1                                    paris, la défense
# 2                                                paris
# 3                                      moussy-le-vieux
# 4                                               france
# ..                                                 ...
# 225                                         saint-ouen
# 226                                              paris
# 227                               boulogne-billancourt
# 228  neuilly sur seine, 38.000,00 € - 50.000,00 € / an
# 229                                         saint-ouen
#
#                                        competences  \
# 0                               sql, t-sql, outils
# 1        support, outils, agile, design, big, data
# 2             crm, data, quality, sql, sas, python
# 3                                 si, support, sap
# 4          outils, support, decisionnel, sql, test
# ..                                             ...
# 225         sap, abap, progiciel, système, support
# 226     digital, outils, securité, sécurité, t-sql
# 227             test, serveur, jquery, mobile, tdd
# 228    nosql, unix, java, machine, learning, linux
# 229  big, data, support, python, réseaux, securité
#
#                                          Type de poste   Nom de la société  \
# 0    sept lieues sas, cabinet de recrutement, cdi -...     sept lieues sas
# 1         edf france, client final, cdi - temps plein,          edf france
# 2             hermès, client final, cdi - temps plein,              hermès
# 3             tereos, client final, cdi - temps plein,              tereos
# 4       safran-group, client final, cdi - temps plein,        safran-group
# ..                                                 ...                 ...
# 225     groupe engie, client final, cdi - temps plein,        groupe engie
# 226     groupe engie, client final, cdi - temps plein,        groupe engie
# 227  francaise des jeux, client final, cdi - temps ...  francaise des jeux
# 228                    beezen, esn, cdi - temps plein,              beezen
# 229     groupe engie, client final, cdi - temps plein,        groupe engie
#
#     Type de contrat  salaire_minimum  salaire_maximum
# 0               cdi              NaN              NaN
# 1               cdi              NaN              NaN
# 2               cdi              NaN              NaN
# 3               cdi              NaN              NaN
# 4               cdi              NaN              NaN
# ..              ...              ...              ...
# 225             cdi              NaN              NaN
# 226             cdi              NaN              NaN
# 227             cdi              NaN              NaN
# 228             cdi          38000.0          50000.0
# 229             cdi              NaN              NaN
#
# [230 rows x 9 columns]

# %%
# médianne = 60 000
median_max = 60000
df['salaire_maximum'].describe()
# Out:
# count        42.000000
# mean      62428.571429
# std       10965.895817
# min       45000.000000
# 25%       55250.000000
# 50%       60000.000000
# 75%       65000.000000
# max      100000.000000
# Name: salaire_maximum, dtype: float64

# %%
# médianne = 45 000 
median_min = 45000
df['salaire_minimum'].describe()
# Out:
# count       42.000000
# mean     47476.190476
# std      10523.465290
# min      30000.000000
# 25%      40000.000000
# 50%      45000.000000
# 75%      59250.000000
# max      70000.000000
# Name: salaire_minimum, dtype: float64

# %%
df['salaire_minimum'].fillna(median_min, inplace=True)
df['salaire_maximum'].fillna(median_max, inplace=True)
df
# Out:
#                                      Intitulé du poste Date de publication  \
# 0                             data analyst - publicité          2022-12-25
# 1                                   data analyst - h/f          2022-12-18
# 2                          customer data analyst (h/f)          2022-12-19
# 3                              master data analyst h/f          2022-12-25
# 4                           portfolio data analyst h/f          2023-01-12
# ..                                                 ...                 ...
# 225                          sap fiori developer (h/f)          2022-12-19
# 226           engie digital - architecte données (h/f)          2023-01-12
# 227  quality assurance - lead qa - lead acceptance h/f          2023-01-15
# 228                                     data scientist          2022-12-30
# 229                                datascientist (h/f)          2023-01-12
#
#                                                   lieu  \
# 0                                                paris
# 1                                    paris, la défense
# 2                                                paris
# 3                                      moussy-le-vieux
# 4                                               france
# ..                                                 ...
# 225                                         saint-ouen
# 226                                              paris
# 227                               boulogne-billancourt
# 228  neuilly sur seine, 38.000,00 € - 50.000,00 € / an
# 229                                         saint-ouen
#
#                                        competences  \
# 0                               sql, t-sql, outils
# 1        support, outils, agile, design, big, data
# 2             crm, data, quality, sql, sas, python
# 3                                 si, support, sap
# 4          outils, support, decisionnel, sql, test
# ..                                             ...
# 225         sap, abap, progiciel, système, support
# 226     digital, outils, securité, sécurité, t-sql
# 227             test, serveur, jquery, mobile, tdd
# 228    nosql, unix, java, machine, learning, linux
# 229  big, data, support, python, réseaux, securité
#
#                                          Type de poste   Nom de la société  \
# 0    sept lieues sas, cabinet de recrutement, cdi -...     sept lieues sas
# 1         edf france, client final, cdi - temps plein,          edf france
# 2             hermès, client final, cdi - temps plein,              hermès
# 3             tereos, client final, cdi - temps plein,              tereos
# 4       safran-group, client final, cdi - temps plein,        safran-group
# ..                                                 ...                 ...
# 225     groupe engie, client final, cdi - temps plein,        groupe engie
# 226     groupe engie, client final, cdi - temps plein,        groupe engie
# 227  francaise des jeux, client final, cdi - temps ...  francaise des jeux
# 228                    beezen, esn, cdi - temps plein,              beezen
# 229     groupe engie, client final, cdi - temps plein,        groupe engie
#
#     Type de contrat  salaire_minimum  salaire_maximum
# 0               cdi          45000.0          60000.0
# 1               cdi          45000.0          60000.0
# 2               cdi          45000.0          60000.0
# 3               cdi          45000.0          60000.0
# 4               cdi          45000.0          60000.0
# ..              ...              ...              ...
# 225             cdi          45000.0          60000.0
# 226             cdi          45000.0          60000.0
# 227             cdi          45000.0          60000.0
# 228             cdi          38000.0          50000.0
# 229             cdi          45000.0          60000.0
#
# [230 rows x 9 columns]

# %%
lieu = [item.split() for item in df['lieu']]
liste_lieu = []
for item in lieu:
    if len(item) > 5:
        liste_lieu.append(' '.join(item).split(',')[0])
    else:
        liste_lieu.append(' '.join(item))
liste_lieu
df['lieu'] = liste_lieu

# %%
df = df.drop('Type de poste', axis=1)
df
# Out:
#                                      Intitulé du poste Date de publication  \
# 0                             data analyst - publicité          2022-12-25
# 1                                   data analyst - h/f          2022-12-18
# 2                          customer data analyst (h/f)          2022-12-19
# 3                              master data analyst h/f          2022-12-25
# 4                           portfolio data analyst h/f          2023-01-12
# ..                                                 ...                 ...
# 225                          sap fiori developer (h/f)          2022-12-19
# 226           engie digital - architecte données (h/f)          2023-01-12
# 227  quality assurance - lead qa - lead acceptance h/f          2023-01-15
# 228                                     data scientist          2022-12-30
# 229                                datascientist (h/f)          2023-01-12
#
#                      lieu                                    competences  \
# 0                   paris                             sql, t-sql, outils
# 1       paris, la défense      support, outils, agile, design, big, data
# 2                   paris           crm, data, quality, sql, sas, python
# 3         moussy-le-vieux                               si, support, sap
# 4                  france        outils, support, decisionnel, sql, test
# ..                    ...                                            ...
# 225            saint-ouen         sap, abap, progiciel, système, support
# 226                 paris     digital, outils, securité, sécurité, t-sql
# 227  boulogne-billancourt             test, serveur, jquery, mobile, tdd
# 228     neuilly sur seine    nosql, unix, java, machine, learning, linux
# 229            saint-ouen  big, data, support, python, réseaux, securité
#
#       Nom de la société Type de contrat  salaire_minimum  salaire_maximum
# 0       sept lieues sas             cdi          45000.0          60000.0
# 1            edf france             cdi          45000.0          60000.0
# 2                hermès             cdi          45000.0          60000.0
# 3                tereos             cdi          45000.0          60000.0
# 4          safran-group             cdi          45000.0          60000.0
# ..                  ...             ...              ...              ...
# 225        groupe engie             cdi          45000.0          60000.0
# 226        groupe engie             cdi          45000.0          60000.0
# 227  francaise des jeux             cdi          45000.0          60000.0
# 228              beezen             cdi          38000.0          50000.0
# 229        groupe engie             cdi          45000.0          60000.0
#
# [230 rows x 8 columns]

# %%
# Nettoyage de la colonne Intitulé de poste, mode = data scientist
liste_postes = []
postes = [item for item in df['Intitulé du poste'].str.strip()]
for item in postes:
    print(item)
    if 'business' in item:
        liste_postes.append('business analyst')
    elif 'analyst' in item:
        liste_postes.append('data analyst')
    elif 'scientist' in item:
        liste_postes.append('data scientist')
    elif 'data engineer' in item:
        liste_postes.append('data engineer')
    elif 'chef de projet' in item:
        liste_postes.append('chef de projet')
    elif 'ingénieur' in item:
        liste_postes.append('engineer')
    elif 'architect' in item:
        liste_postes.append('architect')
    elif 'developer' in item:
        liste_postes.append('developer')
    elif 'développeur' in item:
        liste_postes.append('developer')
    elif 'developpeur' in item:
        liste_postes.append('developer')
    elif 'expert' in item:
        liste_postes.append('expert')
    elif 'consultant' in item:
        liste_postes.append('consultant')
    else:
        liste_postes.append('data scientist')
print(len(liste_postes), liste_postes)

df['Intitulé du poste'] = liste_postes
df['Intitulé du poste'].value_counts()
# Out:
# data analyst - publicité
# data analyst - h/f
# customer data analyst (h/f)
# master data analyst h/f
# portfolio data analyst h/f
# data analyst bo/qlick sense (h/f)
# product data analyst - bi - h/f
# data analyst / chef de projet bi (h/f)
# business analyst senior data crm - paris h/f
# data scientist / analyst and software development f/h
# data analyst (h/f) – mobile gaming - gaminho
# responsable analyses et data relation clients assurances dommages-(h/f)
# data ingenieur f/h
# alternant - data analyst - statistiques prédictiveset connaissance client (h/f)
# data scientist - cdi
# ingénieur mco cybersoc f/h
# consultant data h/f
# data engineer big data - h/f
# data quality manager-(h/f)
# chef de projets data - analytics h/f
# senior data engineer - winglet.io
# responsable etudes et projets si h/f
# ingénieur bi & big data stagiaire f/h
# stage bi & big data #3 f/h
# ingénieur d’affaires / business developer–data h/f
# business developer – ia / data analytics h/f
# business analyst / solution owner - life sciences
# data engineer - h/f
# business analyst / business intelligence
# stagiaire ingénieur big data/ intelligence artificielle h/f h/f
# global technical seo manager
# technicien support informatique h/f
# investor relations professional
# agile business analyst
# alternance - analyse de sensibilité des données métier et mise en oeuvre du référentiel data/big data - h/f
# data scientist
# junior data scientist - winglet.io
# senior data scientist - winglet.io
# data scientist
# stage data analyst-(h/f)
# digital analyst ecommerce (h/f)
# data quality coordination manager-(h/f)
# ingénieur cybersécurité h/f
# business analyst (data) - client final (private equity)  - cdi - 50/80k€ - 75
# adjoint au responsable des solutions business intelligence - h/f
# consultant cognos f/h
# chief data scientist-(h/f)
# data science engineer - danone is/it
# analyste fonctionnel bi microsoft (h/f)
# stage - chargé de projet data référentiel clients-(h/f)
# data manager h/f
# expert data protection & data privacy management
# expert data protection & data privacy management-(h/f)
# chef de projet data
# responsable protection des données personnelles pour le data office groupe-(h/f)
# 2016-433 - data engineer h/f
# data scientist – stage 6 mois
# stagiaire ingénieur de test (h/f)
# architecte logiciel (h/f)
# chef de projet web analyses f/h
# data analyst - publicité
# data analyst - h/f
# customer data analyst (h/f)
# master data analyst h/f
# portfolio data analyst h/f
# data analyst bo/qlick sense (h/f)
# product data analyst - bi - h/f
# data analyst / chef de projet bi (h/f)
# business analyst senior data crm - paris h/f
# data scientist / analyst and software development f/h
# data analyst (h/f) – mobile gaming - gaminho
# responsable analyses et data relation clients assurances dommages-(h/f)
# data ingenieur f/h
# alternant - data analyst - statistiques prédictiveset connaissance client (h/f)
# data scientist - cdi
# ingénieur mco cybersoc f/h
# consultant data h/f
# data engineer big data - h/f
# data quality manager-(h/f)
# chef de projets data - analytics h/f
# ingénieur sécurité cloud f/h
# contrôleur data quality - h/f
# full stack web data viz-(h/f)
# architecte sécurité cloud f/h
# developpeur junior (h/f)
# consultant technico - fonctionnel salesforce h/f
# chef de projet informatique fonctionnel bi
# apprenti(e) – assistant(e) décisionnel business intelligence/big data h/f
# 2018-788 - stage - data et monétisation h/f
# développeur full stack (h/f)
# technicien de maintenance et support utilisateurs h/f
# it expert solutions (mdm) h/f
# stage bi analyste h/f - juillet 2019
# senior data scientist - services h/f
# model builder / consultant fonctionnel anaplan
# ingénieur réseau/sécurité h/f
# manager leader – business analyst titres (h/f)
# ingénieur docker/kubernetes/jenkins/ansible h/f
# ingénieur virtualisation h/f
# ingénieur etudes et développement qlik h/f
# post-doctorant ia/big data h/f
# responsable développement supply chain (f/h) - cdi
# ingénieur système vmware h/f
# consultant bi junior - direction technique f/h
# ingénieur cloud opensource h/f
# application engineer
# stage - chargé d'intégration de nouvelles sources de données dans le datalake et transformation en pyspark-(h/f)
# agile business analyst-(h/f)
# ingénieur de production $u h/f
# ingénieur réseau cisco h/f
# conultant/analyste décisionnel etl (qlikview & talend)- h/f
# chef de projet data moa – banque des territoires
# apprenti data visualisation (h/f)
# data scientist
# alternance - data project manager-(h/f)
# data scientist senior h/f
# architecte technique big data h/f
# senior data scientist - manufacturing h/f
# consultant qliksense f/h
# dceo cluster manager
# développeur vba / excel (h/f) – paris (75)
# stage - business analyst it - h/f
# business analyst (h/f)
# consultant confirmé talend f/h
# ingénieur études et développement php (h/f)
# ingénieurs middleware h/f
# architecte infrastructure it h/f
# ingénieur cloud aws h/f
# product owner - vision 360 tiers en environnement big data-(h/f)
# stage - assistant maitrise d'ouvrage bancaire qualité des données-(h/f)
# data/software engineer h/f
# consultant sénior cognos f/h
# expert technique h/f
# stage - analyses de données sur la durée de vie des freins carbone h/f
# data manager h/f
# stage ingénieur développement d'algorithmes d'analyse de données de vol h/f
# 2019-moa-data-30912 - chef de projets moa data h/f
# développeur big data / python (h/f)
# alternance - assistant marketing private market-(h/f)
# architecte poste de travail h/f
# ingénieur de production cloud h/f
# ingénieur réseaux et sécurité h/f
# ingénieur qa h/f
# stage ingénieur développement d'algorithmes d'analyse de données de vol h/f
# ingénieurs de production unix/linux/windows h/f
# networking cloud support engineer aws
# ingénieur systèmes linux / devops h/f
# ingénieur devops h/f
# alternance - bigdata datascience - h/f
# ingénieur de production cloud h/f
# ingénieur/développeur en ia
# consultant(e) web analyst h/f
# chef de projet crm h/f
# développeur java / j2ee (h/f) – paris (75)
# stage - ingénierie linguistique : détection de similarité sémantique - h/f
# développeur cloud interne d'orange france
# ingénieur cloud azure h/f
# cdi chef de projet bi h/f
# développeur angular (h/f) – paris (75)
# assistant chef de projet social media (paris sportifs) h/f
# alternance - ingénieur etude et développement-(h/f)
# développeur ios h/f
# développeur backend c++/python h/f
# expert middleware h/f
# expert protection des données personnelles et digitales h/f
# consultant(e) confirmé sas / bi h/f
# stage - data engineer h/f
# stage : modélisation de bus numériques dans l'outil plm 3dexperience
# architecte technique senior - squadeasy
# is analyst customer service (danone is/it for sales applications)
# stage marketing/statistique sur le pricing de nos produits- h/f
# technical leader senior hadoop / big data-(h/f)
# consultant avant-vente sauvegarde f/h
# chef de projets it digitaux f/h
# ingénieur système unix/linux h/f
# ingénieur développement logiciel embarqué h/f
# ingénieur support applicatif f/h
# correspondant(e) à la protection des données personnelles-(h/f)
# apprenti(e) – business analyst amoa (information management office - imo) h/f
# ingénieur traitements de données h/f
# responsable technique web - poste en interne (client final réputé) - projet de transformation –grand groupe, paris, cdi 65-70 k€
# ingénieur logiciel - java h/f
# alternance - datascientist junior - h/f
# ingénieur etudes et développement bi (stagiaire) f/h
# analyste fonctionnel sap sd f/h
# assistant(e) comptable-(h/f)
# spécialiste modélisation dynamique de la performance atelier montage h/f
# référent(e) conformité regulatory expertise oversight / responsable data protection et digital-(h/f)
# ingénieur d'affaires it grands comptes paris h/f
# stage tableau de bord 'data centric' pour le pilotage activités de vérification h/f
# ingénieur cyber-sécurité produit h/f
# alternant - concepteur logiciel h/f
# chef de projet recette h/f
# chef de projets recette h/f
# alternance - concepteur logiciel h/f
# equity pricing library project manager (h/f)
# ingénieur avant-vente f/h
# technicien informatique – centre de support f/h
# alternance - assistant knowledge user experience-(h/f)
# concepteur logiciel h/f
# alternance - chargé de sécurité et risque opérationnel infrastructure it reseau-(h/f)
# référent applicatif - expert icm (h/f)
# developpeur agile-(h/f)
# technical leader h/f-(h/f)
# auditeur interne - filiere risques-(h/f)
# internship: root cause analysis in complex distributed systems (h/f)
# developpeur agile-(h/f)
# developpeur agile-(h/f)
# ingénieur systèmes windows h/f
# lead developer – expert java full stack (h/f)
# alternance - concepteur logiciel h/f
# concepteur développeur (h/f)
# architecte technique-(h/f)
# alternance - chargé d'etudes et développement informatique java - bigdata-(h/f)
# consultant msbi (h/f)
# architecte cybersécurité h/f
# stage - développeur / software craftsmanship-(h/f)
# alternance - concepteur logiciel h/f
# architecte logiciel h/f
# expert infrastructures-(h/f)
# expert infrastructures scheduling-(h/f)
# référent applicatif business intelligence bi4 h/f
# concepteur logiciel h/f
# responsable de l’architecture & interopérabilité - h/f
# chef de projet senior risque de crédit (h/f)
# sap fiori developer (h/f)
# engie digital - architecte données (h/f)
# quality assurance - lead qa - lead acceptance h/f
# data scientist
# datascientist (h/f)
# 230 ['data analyst', 'data analyst', 'data analyst', 'data analyst', 'data analyst', 'data analyst', 'data analyst', 'data analyst', 'business analyst', 'data analyst', 'data analyst', -99, -99, 'data analyst', 'data scientist', 'engineer', 'consultant', 'data engineer', -99, 'chef de projet', 'data engineer', -99, 'engineer', -99, 'business analyst', 'business analyst', 'business analyst', 'data engineer', 'business analyst', 'engineer', -99, -99, -99, 'business analyst', -99, 'data scientist', 'data scientist', 'data scientist', 'data scientist', 'data analyst', 'data analyst', -99, 'engineer', 'business analyst', 'business analyst', 'consultant', 'data scientist', -99, 'data analyst', -99, -99, 'expert', 'expert', 'chef de projet', -99, 'data engineer', 'data scientist', 'engineer', 'architect', 'chef de projet', 'data analyst', 'data analyst', 'data analyst', 'data analyst', 'data analyst', 'data analyst', 'data analyst', 'data analyst', 'business analyst', 'data analyst', 'data analyst', -99, -99, 'data analyst', 'data scientist', 'engineer', 'consultant', 'data engineer', -99, 'chef de projet', 'engineer', -99, -99, 'architect', 'developer', 'consultant', 'chef de projet', 'business analyst', -99, 'developer', -99, 'expert', 'data analyst', 'data scientist', 'consultant', 'engineer', 'business analyst', 'engineer', 'engineer', 'engineer', -99, -99, 'engineer', 'consultant', 'engineer', -99, -99, 'business analyst', 'engineer', 'engineer', 'data analyst', 'chef de projet', -99, 'data scientist', -99, 'data scientist', 'architect', 'data scientist', 'consultant', -99, 'developer', 'business analyst', 'business analyst', 'consultant', 'engineer', 'engineer', 'architect', 'engineer', -99, -99, -99, 'consultant', 'expert', -99, -99, 'engineer', 'chef de projet', 'developer', -99, 'architect', 'engineer', 'engineer', 'engineer', 'engineer', 'engineer', -99, 'engineer', 'engineer', -99, 'engineer', 'engineer', 'data analyst', 'chef de projet', 'developer', -99, 'developer', 'engineer', 'chef de projet', 'developer', 'chef de projet', 'engineer', 'developer', 'developer', 'expert', 'expert', 'consultant', 'data engineer', -99, 'architect', 'data analyst', -99, -99, 'consultant', 'chef de projet', 'engineer', 'engineer', 'engineer', -99, 'business analyst', 'engineer', -99, 'engineer', -99, 'engineer', 'data analyst', -99, -99, 'expert', 'engineer', -99, 'engineer', -99, 'chef de projet', 'chef de projet', -99, -99, 'engineer', -99, -99, -99, -99, 'expert', 'developer', -99, -99, -99, 'developer', 'developer', 'engineer', 'developer', -99, 'developer', 'architect', -99, 'consultant', 'architect', 'developer', -99, 'architect', 'expert', 'expert', 'business analyst', -99, 'architect', 'chef de projet', 'developer', 'architect', -99, 'data scientist', -99]
# -99                 62
# engineer            40
# data analyst        30
# business analyst    16
# developer           16
# chef de projet      14
# data scientist      13
# consultant          12
# architect           11
# expert              10
# data engineer        6
# Name: Intitulé du poste, dtype: int64

# %%
df.to_csv('clean_data.csv')
